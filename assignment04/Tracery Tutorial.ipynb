# %% [markdown]
# # Tracery Exercise #
# as shown here "https://github.com/aparrish/rwet/blob/master/tracery-and-python.ipynb"

# %%
# !pip install tracery
# Out:
# Requirement already satisfied: tracery in c:\programdata\anaconda3\lib\site-packages
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import tracery

# %%
rules = { "origin": "Hello, world!"}

# %%
grammar = tracery.Grammar(rules)

# %% [markdown]
# The code above creates a tracery grammar object

# %%
grammar.flatten("origin")
# Out:
# 'origin'

# %%
grammar.flatten("#origin#")
# Out:
# 'Hello, world!'

# %% [markdown]
# ? Why the "#" changed the output of the command above? Maybe, without the "#" I'm just calling a string "origin", while "#origin#" means the "object" (don't even know if this is an object), or "container" that has "Hello, world!" inside.

# %% [markdown]
# Now, for a Tracery grammar with **two rules**. This is custom version of the example shown in the tutorial.

# %%
rules = {
    "origin": "Greetings, #noun#, you were #adjective#.",
    "noun": "oligarch", 
    "adjective": "expected"
}
grammar = tracery.Grammar(rules)
grammar.flatten("#origin#")
# Out:
# 'Greetings, oligarch, you were expected.'

# %% [markdown]
# This seems to answer my question about the "#":
# *When the Tracery generator encounters text that looks like this---a word surrounded by # signs---it looks in the grammar for a rule with the same name as the word, and replaces the text with the expansion for that rule.*

# %% [markdown]
# ## Adding aternatives ##
# something like this: "rule": ["alternative one", "alternative two", "alternative three"]
#
# The code bellow wasn't working, so I copied the one in the tutorial. I forgot to add "," after each "object", as well as the last "}" for "rules"

# %%
rules = {
    "origin": "#greetings#, #noun#, you were #adjective#.",
    "greetings": ["Howdy", "Salutations", "Welcome", "Bem Vindo", "Saudacoes"]
    "noun": ["oligarch","patrenach", "monsenhor", "exceletíssimo"]
    "adjective": ["expected", "awaited", "looked for", "deconstructed"]
grammar = tracery.Grammar(rules)
grammar.flatten("#origin#")
# Out:
#   File "<ipython-input-21-bcbadb65752a>", line 4
#     "noun": ["oligarch","patrenach", "monsenhor", "exceletíssimo"]
#          ^
# SyntaxError: invalid syntax

# %%
rules = {
  "origin": "#greeting#, #noun#!",
  "greeting": "Howdy",
  "noun": ["world", "solar system", "galaxy", "local cluster", "universe"]
}
grammar = tracery.Grammar(rules)
grammar.flatten("#origin#")
# Out:
# 'Howdy, universe!'

# %%
rules = {
    "origin": "#greetings#, #noun#, you were #adjective#.",
    "greetings": ["Howdy", "Salutations", "Welcome", "Bem Vindo", "Saudacoes"],
    "noun": ["oligarch","patrenach", "monsenhor", "exceletissimo"],
    "adjective": ["expected", "awaited", "looked for", "deconstructed"]
}
grammar = tracery.Grammar(rules)
grammar.flatten("#origin#")
# Out:
# 'Salutations, oligarch, you were awaited.'

# %% [markdown]
# ## Run the code several times and generate several outputs ##
# Use a ### For loop ### - Python seems to have a weird synthax for this : "for i in range(5):", instead of "for (i=0; i<10; i++):" - which didn't seemed to work.
# Also: use ## print ## before running "grammar.flatten". (why is markdown not working here?)

# %%
rules = {
    "origin": "#greetings#, #noun#, you were #adjective#.",
    "greetings": ["Howdy", "Salutations", "Welcome", "Bem Vindo", "Saudacoes"],
    "noun": ["oligarch","patrenach", "monsenhor", "exceletissimo"],
    "adjective": ["expected", "awaited", "looked for", "deconstructed"]
}
grammar = tracery.Grammar(rules)
for i in range(10):
    print(grammar.flatten("#origin#"))
# Out:
# Bem Vindo, exceletissimo, you were looked for.
# Salutations, monsenhor, you were looked for.
# Howdy, monsenhor, you were looked for.
# Howdy, exceletissimo, you were awaited.
# Saudacoes, monsenhor, you were awaited.
# Bem Vindo, patrenach, you were expected.
# Saudacoes, oligarch, you were deconstructed.
# Bem Vindo, exceletissimo, you were looked for.
# Saudacoes, oligarch, you were looked for.
# Howdy, monsenhor, you were expected.

# %%
{
"description": "Organized components from the Dark Souls III message system",
"templates": [
"**** ahead",
"No **** ahead",
"**** required ahead",
"be wary of ****",
"try ****",
"Could this be a ****?",
"If only I had a ****…",
"visions of ****…",
"Time for ****",
"****",
"****!",
"****?",
"****…",
"Huh. It's a ****…",
"praise the ****!",
"Let there be ****",
"Ahh, ****…"
],
"words": {
creatures = [
"enemy",
"monster",
"mob enemy",
"tough enemy",
"critical foe",
"Hollow",
"pilgrim",
"prisoner",
"monstrosity",
"skeleton",
"ghost",
"beast",
"lizard",
"bug",
"grub",
"crab",
"dwarf",
"giant",
"demon",
"dragon",
"knight",
"sellsword",
"warrior",
"herald",
"bandit",
"assassin",
"sorcerer",
"pyromancer",
"cleric",
"deprived",
"sniper",
"duo",
"trio",
"you",
"you bastard",
"good fellow",
"saint",
"wretch",
"charmer",
"poor soul",
"oddball",
"nimble one",
"laggard",
"moneybags",
"beggar",
"miscreant",
"liar",
"fatty",
"beanpole",
"youth",
"elder",
"old codger",
"old dear",
"merchant",
"artisan",
"master",
"sage",
"champion",
"Lord of Cinder",
"king",
"queen",
"prince",
"princess",
"angel",
"god",
"friend",
"ally",
"spouse",
"covenator",
"Phantom",
"Dark Spirit"
],
"objects": [
"bonfire",
"ember",
"fog wall",
"lever",
"contraption",
"key",
"trap",
"torch",
"door",
"treasure",
"chest",
"something",
"quite something",
"rubbish",
"filth",
"weapon",
"shield",
"projectile",
"armor",
"item",
"ring",
"ore",
"coal",
"transposing kiln",
"scroll",
"umbral ash",
"throne",
"rite",
"coffin",
"cinder",
"ash",
"moon",
"eye",
"brew",
"soup",
"message",
"bloodstain",
"illusion"
],
"techniques": [
"close-ranged battle",
"ranged battle",
"eliminating one at a time",
"luring it out",
"beating to a pulp",
"ambush",
"pincer attack",
"hitting them in one swoop",
"dual-wielding",
"stealth",
"mimicry",
"fleeing",
"charging",
"jumping off",
"dashing through",
"circling around",
"trapping inside",
"rescue",
"Skill",
"sorcery",
"pyromancy",
"miracles",
"pure luck",
"prudence",
"brief respite",
"play dead"
],
"actions": [
"jog",
"dash",
"rolling",
"backstepping",
"jumping",
"attacking",
"jump attack",
"dash attack",
"counter attack",
"stabbing in the back",
"guard stun & stab",
"plunging attack",
"sweeping attack",
"shield breaking",
"blocking",
"parrying",
"locking-on",
"no lock-on",
"two-handing",
"gesture",
"control",
"destroy"
],
"geography": [
"boulder",
"lava",
"poison gas",
"enemy horde",
"forest",
"swamp",
"cave",
"shortcut",
"detour",
"hidden path",
"secret passage",
"dead end",
"labyrinth",
"hole",
"bright spot",
"dark spot",
"open area",
"tight spot",
"safe zone",
"danger zone",
"sniper spot",
"hidding place",
"illusory wall",
"ladder",
"lift",
"gorgeous view",
"looking away",
"overconfidence",
"slip-up",
"oversight",
"fatigue",
"bad luck",
"inattention",
"loss of stamina",
"chance encounter",
"planned encounter"
],
"orientation": [
"front",
"back",
"left",
"right",
"up",
"down",
"below",
"above",
"behind"
],
"body parts": [
"head",
"neck",
"stomach",
"back",
"arm",
"finger",
"leg",
"rear",
"tail",
"wings",
"anywhere",
"tounge",
"right arm",
"left arm",
"thumb",
"indexfinger",
"longfinger",
"ringfinger",
"smallfinger",
"right leg",
"left leg",
"right side",
"left side",
"pincer",
"wheel",
"core",
"mount"
],
"attribute": [
"regular",
"strike",
"thrust",
"slash",
"magic",
"crystal",
"fire",
"chaos",
"lightning",
"blessing",
"dark",
"critical hits",
"bleeding",
"poison",
"toxic",
"frost",
"curse",
"equipment breakage"
],
"concepts": [
"chance",
"quagmire",
"hint",
"secret",
"sleeptalk",
"happiness",
"misfortune",
"life",
"death",
"demise",
"joy",
"fury",
"agony",
"sadness",
"tears",
"loyalty",
"betrayal",
"hope",
"despair",
"fear",
"losing sanity",
"victory",
"defeat",
"sacrafice",
"light",
"dark",
"bravery",
"confidence",
"vigor",
"revenge",
"resignation",
"overwhelming",
"regret",
"pointless",
"man",
"woman",
"friendship",
"love",
"recklessness",
"composure",
"guts",
"comfort",
"silence",
"deep",
"dregs"
],
"musings": [
"good luck",
"fine work",
"I did it!",
"I've failed…",
"here!",
"not here!",
"I can't take this…",
"lonely…",
"don't you dare!",
"do it!",
"look carefully",
"listen carefully",
"think carefully",
"this place again?",
"now the real fight begins",
"you don't deserve this",
"keep moving",
"pull back",
"give it up",
"don't give up",
"help me…",
"impossible…",
"bloody expensive…",
"let me out of here…",
"stay calm",
"like a dream…",
"seems familiar…",
"are you ready?",
"it'll happen to you too",
"praise the Sun!",
"may the flames guide thee"
]
}
}
# Out:
# {'description': 'Organized components from the Dark Souls III message system',
#  'templates': ['**** ahead',
#   'No **** ahead',
#   '**** required ahead',
#   'be wary of ****',
#   'try ****',
#   'Could this be a ****?',
#   'If only I had a ****…',
#   'visions of ****…',
#   'Time for ****',
#   '****',
#   '****!',
#   '****?',
#   '****…',
#   "Huh. It's a ****…",
#   'praise the ****!',
#   'Let there be ****',
#   'Ahh, ****…'],
#  'words': {'actions': ['jog',
#    'dash',
#    'rolling',
#    'backstepping',
#    'jumping',
#    'attacking',
#    'jump attack',
#    'dash attack',
#    'counter attack',
#    'stabbing in the back',
#    'guard stun & stab',
#    'plunging attack',
#    'sweeping attack',
#    'shield breaking',
#    'blocking',
#    'parrying',
#    'locking-on',
#    'no lock-on',
#    'two-handing',
#    'gesture',
#    'control',
#    'destroy'],
#   'attribute': ['regular',
#    'strike',
#    'thrust',
#    'slash',
#    'magic',
#    'crystal',
#    'fire',
#    'chaos',
#    'lightning',
#    'blessing',
#    'dark',
#    'critical hits',
#    'bleeding',
#    'poison',
#    'toxic',
#    'frost',
#    'curse',
#    'equipment breakage'],
#   'body parts': ['head',
#    'neck',
#    'stomach',
#    'back',
#    'arm',
#    'finger',
#    'leg',
#    'rear',
#    'tail',
#    'wings',
#    'anywhere',
#    'tounge',
#    'right arm',
#    'left arm',
#    'thumb',
#    'indexfinger',
#    'longfinger',
#    'ringfinger',
#    'smallfinger',
#    'right leg',
#    'left leg',
#    'right side',
#    'left side',
#    'pincer',
#    'wheel',
#    'core',
#    'mount'],
#   'concepts': ['chance',
#    'quagmire',
#    'hint',
#    'secret',
#    'sleeptalk',
#    'happiness',
#    'misfortune',
#    'life',
#    'death',
#    'demise',
#    'joy',
#    'fury',
#    'agony',
#    'sadness',
#    'tears',
#    'loyalty',
#    'betrayal',
#    'hope',
#    'despair',
#    'fear',
#    'losing sanity',
#    'victory',
#    'defeat',
#    'sacrafice',
#    'light',
#    'dark',
#    'bravery',
#    'confidence',
#    'vigor',
#    'revenge',
#    'resignation',
#    'overwhelming',
#    'regret',
#    'pointless',
#    'man',
#    'woman',
#    'friendship',
#    'love',
#    'recklessness',
#    'composure',
#    'guts',
#    'comfort',
#    'silence',
#    'deep',
#    'dregs'],
#   'creatures': ['enemy',
#    'monster',
#    'mob enemy',
#    'tough enemy',
#    'critical foe',
#    'Hollow',
#    'pilgrim',
#    'prisoner',
#    'monstrosity',
#    'skeleton',
#    'ghost',
#    'beast',
#    'lizard',
#    'bug',
#    'grub',
#    'crab',
#    'dwarf',
#    'giant',
#    'demon',
#    'dragon',
#    'knight',
#    'sellsword',
#    'warrior',
#    'herald',
#    'bandit',
#    'assassin',
#    'sorcerer',
#    'pyromancer',
#    'cleric',
#    'deprived',
#    'sniper',
#    'duo',
#    'trio',
#    'you',
#    'you bastard',
#    'good fellow',
#    'saint',
#    'wretch',
#    'charmer',
#    'poor soul',
#    'oddball',
#    'nimble one',
#    'laggard',
#    'moneybags',
#    'beggar',
#    'miscreant',
#    'liar',
#    'fatty',
#    'beanpole',
#    'youth',
#    'elder',
#    'old codger',
#    'old dear',
#    'merchant',
#    'artisan',
#    'master',
#    'sage',
#    'champion',
#    'Lord of Cinder',
#    'king',
#    'queen',
#    'prince',
#    'princess',
#    'angel',
#    'god',
#    'friend',
#    'ally',
#    'spouse',
#    'covenator',
#    'Phantom',
#    'Dark Spirit'],
#   'geography': ['boulder',
#    'lava',
#    'poison gas',
#    'enemy horde',
#    'forest',
#    'swamp',
#    'cave',
#    'shortcut',
#    'detour',
#    'hidden path',
#    'secret passage',
#    'dead end',
#    'labyrinth',
#    'hole',
#    'bright spot',
#    'dark spot',
#    'open area',
#    'tight spot',
#    'safe zone',
#    'danger zone',
#    'sniper spot',
#    'hidding place',
#    'illusory wall',
#    'ladder',
#    'lift',
#    'gorgeous view',
#    'looking away',
#    'overconfidence',
#    'slip-up',
#    'oversight',
#    'fatigue',
#    'bad luck',
#    'inattention',
#    'loss of stamina',
#    'chance encounter',
#    'planned encounter'],
#   'musings': ['good luck',
#    'fine work',
#    'I did it!',
#    "I've failed…",
#    'here!',
#    'not here!',
#    "I can't take this…",
#    'lonely…',
#    "don't you dare!",
#    'do it!',
#    'look carefully',
#    'listen carefully',
#    'think carefully',
#    'this place again?',
#    'now the real fight begins',
#    "you don't deserve this",
#    'keep moving',
#    'pull back',
#    'give it up',
#    "don't give up",
#    'help me…',
#    'impossible…',
#    'bloody expensive…',
#    'let me out of here…',
#    'stay calm',
#    'like a dream…',
#    'seems familiar…',
#    'are you ready?',
#    "it'll happen to you too",
#    'praise the Sun!',
#    'may the flames guide thee'],
#   'objects': ['bonfire',
#    'ember',
#    'fog wall',
#    'lever',
#    'contraption',
#    'key',
#    'trap',
#    'torch',
#    'door',
#    'treasure',
#    'chest',
#    'something',
#    'quite something',
#    'rubbish',
#    'filth',
#    'weapon',
#    'shield',
#    'projectile',
#    'armor',
#    'item',
#    'ring',
#    'ore',
#    'coal',
#    'transposing kiln',
#    'scroll',
#    'umbral ash',
#    'throne',
#    'rite',
#    'coffin',
#    'cinder',
#    'ash',
#    'moon',
#    'eye',
#    'brew',
#    'soup',
#    'message',
#    'bloodstain',
#    'illusion'],
#   'orientation': ['front',
#    'back',
#    'left',
#    'right',
#    'up',
#    'down',
#    'below',
#    'above',
#    'behind'],
#   'techniques': ['close-ranged battle',
#    'ranged battle',
#    'eliminating one at a time',
#    'luring it out',
#    'beating to a pulp',
#    'ambush',
#    'pincer attack',
#    'hitting them in one swoop',
#    'dual-wielding',
#    'stealth',
#    'mimicry',
#    'fleeing',
#    'charging',
#    'jumping off',
#    'dashing through',
#    'circling around',
#    'trapping inside',
#    'rescue',
#    'Skill',
#    'sorcery',
#    'pyromancy',
#    'miracles',
#    'pure luck',
#    'prudence',
#    'brief respite',
#    'play dead']}}

# %%
rules = {
    "origin": "If only I had more #objects# in my house! But there is always some #creatures# messing with me.",
    
"objects": words.objects
"creatures": words.creatures
    
}
grammar = tracery.Grammar(rules)
grammar = flatten("#origin#")
# Out:
#   File "<ipython-input-63-c36424a520da>", line 5
#     "creatures": words.creatures
#               ^
# SyntaxError: invalid syntax

# %%
creatures = [
    "enemy",
      "monster",
      "mob enemy",
      "tough enemy",
      "critical foe",
      "Hollow",
      "pilgrim",
      "prisoner",
      "monstrosity",
      "skeleton",
      "ghost",
      "beast",
      "lizard",
      "bug",
      "grub",
      "crab",
      "dwarf",
      "giant",
      "demon",
      "dragon",
      "knight",
      "sellsword",
      "warrior",
      "herald",
      "bandit",
      "assassin",
      "sorcerer",
      "pyromancer",
      "cleric",
      "deprived",
      "sniper",
      "duo",
      "trio",
      "you",
      "you bastard",
      "good fellow",
      "saint",
      "wretch",
      "charmer",
      "poor soul",
      "oddball",
      "nimble one",
      "laggard",
      "moneybags",
      "beggar",
      "miscreant",
      "liar",
      "fatty",
      "beanpole",
      "youth",
      "elder",
      "old codger",
      "old dear",
      "merchant",
      "artisan",
      "master",
      "sage",
      "champion",
      "Lord of Cinder",
      "king",
      "queen",
      "prince",
      "princess",
      "angel",
      "god",
      "friend",
      "ally",
      "spouse",
      "covenator",
      "Phantom",
      "Dark Spirit"
]

# %%
objects = [
      "bonfire",
      "ember",
      "fog wall",
      "lever",
      "contraption",
      "key",
      "trap",
      "torch",
      "door",
      "treasure",
      "chest",
      "something",
      "quite something",
      "rubbish",
      "filth",
      "weapon",
      "shield",
      "projectile",
      "armor",
      "item",
      "ring",
      "ore",
      "coal",
      "transposing kiln",
      "scroll",
      "umbral ash",
      "throne",
      "rite",
      "coffin",
      "cinder",
      "ash",
      "moon",
      "eye",
      "brew",
      "soup",
      "message",
      "bloodstain",
      "illusion"
    ]

# %%
rules = {
    "origin": "If only I had more #object# in my house! But there is always some #creature# messing with me.",
    
"object": objects
"creature": creatures
    
}
grammar = tracery.Grammar(rules)
grammar = flatten("#origin#")
# Out:
#   File "<ipython-input-75-737788325615>", line 5
#     "creature": creatures
#              ^
# SyntaxError: invalid syntax

# %%
creatures = [
    "enemy",
      "monster",
      "mob enemy",
      "tough enemy",
      "critical foe",
      "Hollow",
      "pilgrim",
      "prisoner",
      "monstrosity",
      "skeleton",
      "ghost",
      "beast",
      "lizard",
      "bug",
      "grub",
      "crab",
      "dwarf",
      "giant",
      "demon",
      "dragon",
      "knight",
      "sellsword",
      "warrior",
      "herald",
      "bandit",
      "assassin",
      "sorcerer",
      "pyromancer",
      "cleric",
      "deprived",
      "sniper",
      "duo",
      "trio",
      "you",
      "you bastard",
      "good fellow",
      "saint",
      "wretch",
      "charmer",
      "poor soul",
      "oddball",
      "nimble one",
      "laggard",
      "moneybags",
      "beggar",
      "miscreant",
      "liar",
      "fatty",
      "beanpole",
      "youth",
      "elder",
      "old codger",
      "old dear",
      "merchant",
      "artisan",
      "master",
      "sage",
      "champion",
      "Lord of Cinder",
      "king",
      "queen",
      "prince",
      "princess",
      "angel",
      "god",
      "friend",
      "ally",
      "spouse",
      "covenator",
      "Phantom",
      "Dark Spirit"
]

# %%
objects = [
      "bonfire",
      "ember",
      "fog wall",
      "lever",
      "contraption",
      "key",
      "trap",
      "torch",
      "door",
      "treasure",
      "chest",
      "something",
      "quite something",
      "rubbish",
      "filth",
      "weapon",
      "shield",
      "projectile",
      "armor",
      "item",
      "ring",
      "ore",
      "coal",
      "transposing kiln",
      "scroll",
      "umbral ash",
      "throne",
      "rite",
      "coffin",
      "cinder",
      "ash",
      "moon",
      "eye",
      "brew",
      "soup",
      "message",
      "bloodstain",
      "illusion"
    ]

# %%
rules = {
    "origin": "If only I had more #object# in my house! But there is always some #creature# messing with me.",
    
"object": objects,
"creature": creatures
    
}
grammar = tracery.Grammar(rules)

for i in range(10):
    print(grammar.flatten("#origin#"))
# Out:
# If only I had more projectile in my house! But there is always some deprived messing with me.
# If only I had more contraption in my house! But there is always some miscreant messing with me.
# If only I had more eye in my house! But there is always some god messing with me.
# If only I had more something in my house! But there is always some angel messing with me.
# If only I had more eye in my house! But there is always some Hollow messing with me.
# If only I had more coffin in my house! But there is always some old codger messing with me.
# If only I had more cinder in my house! But there is always some pyromancer messing with me.
# If only I had more throne in my house! But there is always some deprived messing with me.
# If only I had more shield in my house! But there is always some Phantom messing with me.
# If only I had more bonfire in my house! But there is always some grub messing with me.

# %% [markdown]
# Again, I was having problems with the code above because of ",". At first I thought it was something with my dictionary "creatures". But it was only a missing comma. **Coding is fun!** Ah...and I need to check indentation after "print".
#
# What is really fun (and super nerdy) is to use words from the notorious game "Dark Souls" as my dictionary - *thanks corpora!*

# %% [markdown]
# ## Importing "base_english" modifier ##
#
# To fix things like "I'm a accountant" to "I'm a**n** account". But this mistake doesn't show up in my example, so I'll modified it to test the module.
#
# Added ".a" after the #object#

# %%
from tracery.modifiers import base_english

# %%
rules = {
    "origin": "If only I had #object.a# in my house! But there is always some #creature# messing with me.",
    
"object": objects,
"creature": creatures
    
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)

for i in range(10):
    print(grammar.flatten("#origin#"))
# Out:
# If only I had a contraption in my house! But there is always some trio messing with me.
# If only I had a bonfire in my house! But there is always some duo messing with me.
# If only I had an eye in my house! But there is always some merchant messing with me.
# If only I had a filth in my house! But there is always some pyromancer messing with me.
# If only I had a chest in my house! But there is always some god messing with me.
# If only I had a rubbish in my house! But there is always some master messing with me.
# If only I had an illusion in my house! But there is always some covenator messing with me.
# If only I had a torch in my house! But there is always some dwarf messing with me.
# If only I had a coffin in my house! But there is always some sage messing with me.
# If only I had a key in my house! But there is always some warrior messing with me.

# %%
rules = {
    "origin": "If only I had #object.a# in my house! But there is always some #creature.s# messing with me.",
    
"object": objects,
"creature": creatures
    
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)

for i in range(10):
    print(grammar.flatten("#origin#"))
# Out:
# If only I had a fog wall in my house! But there is always some assassins messing with me.
# If only I had a bonfire in my house! But there is always some champions messing with me.
# If only I had a bonfire in my house! But there is always some enemies messing with me.
# If only I had a rubbish in my house! But there is always some sellswords messing with me.
# If only I had a torch in my house! But there is always some sages messing with me.
# If only I had a lever in my house! But there is always some miscreants messing with me.
# If only I had a shield in my house! But there is always some monstrosities messing with me.
# If only I had a transposing kiln in my house! But there is always some beanpoles messing with me.
# If only I had a contraption in my house! But there is always some wretches messing with me.
# If only I had an ash in my house! But there is always some masters messing with me.

# %% [markdown]
# ## Generate several rules from the same initial rule ##

# %%
rules = {
    "origin": ["If only I had #object.a# in my house! But there is always some #creature# messing with me."
             , "That guy only dates #creature.s# that are into #object.s#!"
              ]  , 
"object": objects,
"creature": creatures
    
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)

for i in range(10):
    print(grammar.flatten("#origin#"))
# Out:
# If only I had a trap in my house! But there is always some trio messing with me.
# That guy only dates moneybagses that are into messages!
# If only I had a trap in my house! But there is always some bandit messing with me.
# That guy only dates fatties that are into bonfires!
# That guy only dates youthes that are into eyes!
# If only I had an eye in my house! But there is always some charmer messing with me.
# That guy only dates liars that are into filthes!
# If only I had a lever in my house! But there is always some assassin messing with me.
# If only I had an umbral ash in my house! But there is always some spouse messing with me.
# If only I had a bloodstain in my house! But there is always some you bastard messing with me.

# %% [markdown]
# *Hahahaha.....I think I'm creating some kind of "Dark Souls" dating/bar talk. I have to turn this into a webcomic*

# %%
rules = {
    "origin": ["If only I had #object.a# in my house! But there is always some #creature# messing with me."
             , "That guy only dates #creature.s# that are into #object.s#!"
              ,
              "Do you think that love between #creature.a# and #creature.a# is possible?"
              ]  , 
"object": objects,
"creature": creatures
    
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)

for i in range(10):
    print(grammar.flatten("#origin#"))
# Out:
# If only I had a bonfire in my house! But there is always some bug messing with me.
# Do you think that love between a monstrosity and a miscreant is possible?
# If only I had a fog wall in my house! But there is always some Lord of Cinder messing with me.
# Do you think that love between a skeleton and a sniper is possible?
# If only I had a coffin in my house! But there is always some assassin messing with me.
# Do you think that love between a youth and a grub is possible?
# If only I had a ring in my house! But there is always some sellsword messing with me.
# Do you think that love between a spouse and a beast is possible?
# Do you think that love between a Phantom and a grub is possible?
# Do you think that love between a giant and a beanpole is possible?

# %% [markdown]
# ## Rules within rules for realz... ##

# %%
actions = [
      "jog",
      "dash",
      "rolling",
      "backstepping",
      "jumping",
      "attacking",
      "jump attack",
      "dash attack",
      "counter attack",
      "stabbing in the back",
      "guard stun & stab",
      "plunging attack",
      "sweeping attack",
      "shield breaking",
      "blocking",
      "parrying",
      "locking-on",
      "no lock-on",
      "two-handing",
      "gesture",
      "control",
      "destroy"
]

# %%
bodyParts = [
      "head",
      "neck",
      "stomach",
      "back",
      "arm",
      "finger",
      "leg",
      "rear",
      "tail",
      "wings",
      "anywhere",
      "tounge",
      "right arm",
      "left arm",
      "thumb",
      "indexfinger",
      "longfinger",
      "ringfinger",
      "smallfinger",
      "right leg",
      "left leg",
      "right side",
      "left side",
      "pincer",
      "wheel",
      "core",
      "mount"
]

# %%
concepts = [
       "chance",
      "quagmire",
      "hint",
      "secret",
      "sleeptalk",
      "happiness",
      "misfortune",
      "life",
      "death",
      "demise",
      "joy",
      "fury",
      "agony",
      "sadness",
      "tears",
      "loyalty",
      "betrayal",
      "hope",
      "despair",
      "fear",
      "losing sanity",
      "victory",
      "defeat",
      "sacrafice",
      "light",
      "dark",
      "bravery",
      "confidence",
      "vigor",
      "revenge",
      "resignation",
      "overwhelming",
      "regret",
      "pointless",
      "man",
      "woman",
      "friendship",
      "love",
      "recklessness",
      "composure",
      "guts",
      "comfort",
      "silence",
      "deep",
      "dregs"
]

# %% [markdown]
# ### my list of Dark Souls Dictionaries ###
# * objects
# * creatures
# * bodyParts
# * actions
# * concepts
# * conjunctions (I created this one)

# %%
conjunctions = [

"when",
"once",
"as soon as",
"if",
"till",
"untill",
"provided that",
"unless",
"even though",
"although",
"as",
"because",
"after",
"before",
"in spite of",
"despite",

]

# %%
rules = {
    "origin": "#conjunction.capitalize# #action# the #noun# #action# #noun.a#, only #concept# can make #concept# #action.a#.",
    "noun": [ "#creature#", "#bodyPart#", "#concept#"],
    


"object": objects,
"creature": creatures,
"bodyPart": bodyParts,
"action": actions,
"concept": concepts,
"conjunction": conjunctions

}
    
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
for i in range(10): 
    print(grammar.flatten("#origin#"))
# Out:
# Provided that guard stun & stab the merchant counter attack a man, only light can make deep a plunging attack.
# Even though sweeping attack the king stabbing in the back a right leg, only dregs can make man a gesture.
# Once stabbing in the back the mob enemy shield breaking a charmer, only misfortune can make misfortune a control.
# Till rolling the pincer counter attack a friend, only joy can make friendship a locking-on.
# If parrying the critical foe two-handing a crab, only secret can make regret a control.
# Because shield breaking the old codger counter attack a revenge, only secret can make fury a stabbing in the back.
# If parrying the stomach blocking a tears, only losing sanity can make despair a jump attack.
# Even though dash attack the thumb counter attack a knight, only defeat can make woman a jump attack.
# Provided that control the sleeptalk dash a wings, only dark can make tears a destroy.
# In spite of rolling the chance dash attack a dark, only regret can make woman a plunging attack.

# %% [markdown]
# Still crude...keep working on it.
#
# template for a DarkSouls dating dialogue:
# "Do you believe that a Monster can love a Hero? Like when a Monste

# %%
rules = {
    "origin":[ "Do you believe that #creature.a# can love #creature.a#? #conjunction.capitalize# #creature.a# #action# #noun.a# with #object.a#?", 
    "Only when #noun.a# has his or her #bodyPart# tenderly #verb# by #creature.a#, will #creature.a# trully believe in love."],
    "noun": [ "#creature#", "#bodyPart#", "#concept#", "#object#"],
    
"verb": ["kissed", "caressed", "hugged", "stroked", "touched", "rubbed"],

"object": objects,
"creature": creatures,
"bodyPart": bodyParts,
"action": actions,
"concept": concepts,
"conjunction": conjunctions

}
    
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
for i in range(10): 
    print(grammar.flatten("#origin#"))
# Out:
# Do you believe that a beast can love a beggar? Even though a monster jump attack a left arm with a bonfire?
# Do you believe that a poor soul can love a saint? Although a saint dash a god with a door?
# Do you believe that a grub can love a sellsword? Unless a trio plunging attack a ring with a message?
# Do you believe that a cleric can love a duo? As soon as a moneybags rolling a death with a cinder?
# Only when a losing sanity has his or her ringfinger tenderly stroked by a liar, will a warrior trully believe in love.
# Only when a bug has his or her leg tenderly kissed by a pilgrim, will a prince trully believe in love.
# Only when a sacrafice has his or her left leg tenderly kissed by a friend, will a king trully believe in love.
# Only when an oddball has his or her left leg tenderly hugged by a tough enemy, will a laggard trully believe in love.
# Only when a pincer has his or her right leg tenderly kissed by an enemy, will a champion trully believe in love.
# Do you believe that a critical foe can love an assassin? After a merchant sweeping attack a head with a key?

# %%
adverbs = [
        "abnormally",
        "absentmindedly",
        "accidentally",
        "acidly",
        "actually",
        "adventurously",
        "afterwards",
        "almost",
        "always",
        "angrily",
        "annually",
        "anxiously",
        "arrogantly",
        "awkwardly",
        "badly",
        "bashfully",
        "beautifully",
        "bitterly",
        "bleakly",
        "blindly",
        "blissfully",
        "boastfully",
        "boldly",
        "bravely",
        "briefly",
        "brightly",
        "briskly",
        "broadly",
        "busily",
        "calmly",
        "carefully",
        "carelessly",
        "cautiously",
        "certainly",
        "cheerfully",
        "clearly",
        "cleverly",
        "closely",
        "coaxingly",
        "colorfully",
        "commonly",
        "continually",
        "coolly",
        "correctly",
        "courageously",
        "crossly",
        "cruelly",
        "curiously",
        "daily",
        "daintily",
        "dearly",
        "deceivingly",
        "deeply",
        "defiantly",
        "deliberately",
        "delightfully",
        "diligently",
        "dimly",
        "doubtfully",
        "dreamily",
        "easily",
        "elegantly",
        "energetically",
        "enormously",
        "enthusiastically",
        "equally",
        "especially",
        "even",
        "evenly",
        "eventually",
        "exactly",
        "excitedly",
        "extremely",
        "fairly",
        "faithfully",
        "famously",
        "far",
        "fast",
        "fatally",
        "ferociously",
        "fervently",
        "fiercely",
        "fondly",
        "foolishly",
        "fortunately",
        "frankly",
        "frantically",
        "freely",
        "frenetically",
        "frightfully",
        "fully",
        "furiously",
        "generally",
        "generously",
        "gently",
        "gladly",
        "gleefully",
        "gracefully",
        "gratefully",
        "greatly",
        "greedily",
        "happily",
        "hastily",
        "healthily",
        "heavily",
        "helpfully",
        "helplessly",
        "highly",
        "honestly",
        "hopelessly",
        "hourly",
        "hungrily",
        "immediately",
        "innocently",
        "inquisitively",
        "instantly",
        "intensely",
        "intently",
        "interestingly",
        "inwardly",
        "irritably",
        "jaggedly",
        "jealously",
        "joshingly",
        "jovially",
        "joyfully",
        "joyously",
        "jubilantly",
        "judgementally",
        "justly",
        "keenly",
        "kiddingly",
        "kindheartedly",
        "kindly",
        "kissingly",
        "knavishly",
        "knottily",
        "knowingly",
        "knowledgeably",
        "kookily",
        "lazily",
        "less",
        "lightly",
        "likely",
        "limply",
        "lively",
        "loftily",
        "longingly",
        "loosely",
        "loudly",
        "lovingly",
        "loyally",
        "madly",
        "majestically",
        "meaningfully",
        "mechanically",
        "merrily",
        "miserably",
        "mockingly",
        "monthly",
        "more",
        "mortally",
        "mostly",
        "mysteriously",
        "naturally",
        "nearly",
        "neatly",
        "needily",
        "nervously",
        "never",
        "nicely",
        "noisily",
        "not",
        "obediently",
        "obnoxiously",
        "oddly",
        "offensively",
        "officially",
        "often",
        "only",
        "openly",
        "optimistically",
        "overconfidently",
        "owlishly",
        "painfully",
        "partially",
        "patiently",
        "perfectly",
        "physically",
        "playfully",
        "politely",
        "poorly",
        "positively",
        "potentially",
        "powerfully",
        "promptly",
        "properly",
        "punctually",
        "quaintly",
        "quarrelsomely",
        "queasily",
        "queerly",
        "questionably",
        "questioningly",
        "quicker",
        "quickly",
        "quietly",
        "quirkily",
        "quizzically",
        "rapidly",
        "rarely",
        "readily",
        "really",
        "reassuringly",
        "recklessly",
        "regularly",
        "reluctantly",
        "repeatedly",
        "reproachfully",
        "restfully",
        "righteously",
        "rightfully",
        "rigidly",
        "roughly",
        "rudely",
        "sadly",
        "safely",
        "scarcely",
        "scarily",
        "searchingly",
        "sedately",
        "seemingly",
        "seldom",
        "selfishly",
        "separately",
        "seriously",
        "shakily",
        "sharply",
        "sheepishly",
        "shrilly",
        "shyly",
        "silently",
        "sleepily",
        "slowly",
        "smoothly",
        "softly",
        "solemnly",
        "solidly",
        "sometimes",
        "soon",
        "speedily",
        "stealthily",
        "sternly",
        "strictly",
        "successfully",
        "suddenly",
        "surprisingly",
        "suspiciously",
        "sweetly",
        "swiftly",
        "sympathetically",
        "tenderly",
        "tensely",
        "terribly",
        "thankfully",
        "thoroughly",
        "thoughtfully",
        "tightly",
        "tomorrow",
        "too",
        "tremendously",
        "triumphantly",
        "truly",
        "truthfully",
        "ultimately",
        "unabashedly",
        "unaccountably",
        "unbearably",
        "unethically",
        "unexpectedly",
        "unfortunately",
        "unimpressively",
        "unnaturally",
        "unnecessarily",
        "upbeat",
        "upliftingly",
        "upright",
        "upside-down",
        "upward",
        "upwardly",
        "urgently",
        "usefully",
        "uselessly",
        "usually",
        "utterly",
        "vacantly",
        "vaguely",
        "vainly",
        "valiantly",
        "vastly",
        "verbally",
        "very",
        "viciously",
        "victoriously",
        "violently",
        "vivaciously",
        "voluntarily",
        "warmly",
        "weakly",
        "wearily",
        "well",
        "wetly",
        "wholly",
        "wildly",
        "willfully",
        "wisely",
        "woefully",
        "wonderfully",
        "worriedly",
        "wrongly",
        "yawningly",
        "yearly",
        "yearningly",
        "yesterday",
        "yieldingly",
        "youthfully"
    ]

# %%
rules = {
    "origin":[ "Do you believe that #creature.a# can love #creature.a#? #conjunction.capitalize# #creature.a# #action# #noun.a# with #object.a#?", 
    "Only when #noun.a# has his or her #bodyPart# #adverb# #verb# by #creature.a#, will #creature.a# trully believe in love."],
    "noun": [ "#creature#", "#bodyPart#", "#concept#", "#object#"],
    
"verb": ["kissed", "caressed", "hugged", "stroked", "touched", "rubbed"],

"object": objects,
"creature": creatures,
"bodyPart": bodyParts,
"action": actions,
"concept": concepts,
"conjunction": conjunctions,
"adverb": adverbs

}
    
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
for i in range(10): 
    print(grammar.flatten("#origin#"))
# Out:
# Do you believe that a pyromancer can love a knight? Before a ghost jumping a demise with a throne?
# Only when a longfinger has his or her leg unexpectedly rubbed by a Hollow, will a pilgrim trully believe in love.
# Only when a silence has his or her core well rubbed by a Hollow, will an elder trully believe in love.
# Only when a left leg has his or her pincer vaguely kissed by a Lord of Cinder, will a you bastard trully believe in love.
# Only when a finger has his or her left leg queerly touched by a sorcerer, will a deprived trully believe in love.
# Only when a wings has his or her core especially caressed by a skeleton, will a crab trully believe in love.
# Do you believe that a trio can love a giant? Even though a Phantom plunging attack a you with a rite?
# Only when a bonfire has his or her left arm bravely hugged by a giant, will a sorcerer trully believe in love.
# Do you believe that a demon can love a critical foe? Despite an artisan shield breaking a silence with a torch?
# Do you believe that a king can love a fatty? Although a cleric locking-on a coal with a soup?
